# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import probplot

# %%
valorA = np.array([1.2, 0.9, 0.7, 1, 1.7, 1.7, 1.1, 0.9, 1.7, 1.9, 1.3, 2.1, 1.6, 1.8, 1.4, 1.3, 1.9, 1.6, 0.8, 2, 1.7, 1.6, 2.3, 2])
valorB = np.array([1.6, 1.5, 1.1, 2.1, 1.5, 1.3, 1, 2.6])

# %%
valorA = np.array([100, 100, 60, 135, 195, 195, 125, 135, 95, 42, 75, 72])
valorB = np.array([80, 75, 75, 85, 75, 35, 85, 65, 45, 100, 28, 38, 50, 28])

# %%
valorA = np.array([418, 434, 454, 421, 437, 463, 421, 439, 465, 422, 446, 425, 447, 427, 448, 431, 453])
valorB = np.array([429, 430, 430, 431, 436, 437, 440, 441, 445, 446, 447])

# %%
fig, ax = plt.subplots()
probplot(valorA, fit=True, plot=ax)
plt.show()

# %%
fig, ax = plt.subplots()
probplot(valorB, fit=True, plot=ax)
plt.show()

# %%
plt.boxplot([valorA, valorB], vert=False)
plt.show()

# %%
valorB.mean()
# Out:
# 437.45454545454544

# %%
valorB.std(ddof=1)
# Out:
# 6.831744087180613

# %%
len(valorB)
# Out:
# 11

# %% [markdown]
# # seção 3

# %%
dados = np.array([11, 164, 225, -9, 169, 442, -312, 69, 137, 157, -54, 350, 452, 540])

# %%
fig, ax = plt.subplots()
probplot(valorB, fit=True, plot=ax)
plt.show()

# %%
dados.mean().round(3)
# Out:
# 167.214

# %%
dados.std(ddof=1).round(3)
# Out:
# 228.211

# %% [markdown]
# # Seção 5

# %%
dados1 = np.array([29, 34, 33, 27, 28, 32, 31, 34, 32, 27])
dados2 = np.array([18, 15, 23, 13, 12])

# %%
print("Média: ", dados2.mean())
print("Desvio padrão: ", dados2.std(ddof=1).round(2))
print("Tamanho: ", len(dados2))
# Out:
# Média:  16.2
# Desvio padrão:  4.44
# Tamanho:  5
