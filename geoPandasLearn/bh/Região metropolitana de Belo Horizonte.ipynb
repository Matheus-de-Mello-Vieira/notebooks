# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
from random import randrange
import numpy as np

# %%
map_df = gpd.read_file("regiao_metropolitana_bh-polygon/regiao_metropolitana_bh-polygon.shp")

# %%
print(map_df["Name"].values)
# Out:
# ['Belo Horizonte' 'Ibirité' 'Caeté' 'Capim Branco' 'Confins' 'Esmeraldas'
#  'Florestal' 'Igarapé' 'Itaguara' 'Itatiaiuçu' 'Nova União' 'Juatuba'
#  'Mário Campos' 'Mateus Leme' 'Matozinhos' 'Raposos' 'Ribeirão das Neves'
#  'Sabará' 'São Joaquim de Bicas' 'São José da Lapa' 'Sarzedo'
#  'Taquaraçu de Minas' 'Vespasiano' 'Baldim' 'Betim' 'Brumadinho'
#  'Contagem' 'Lagoa Santa' 'Jaboticatubas' 'Nova Lima' 'Pedro Leopoldo'
#  'Rio Acima' 'Rio Manso' 'Santa Luzia']

# %% [markdown]
# ## Plotando BH toda

# %%
map_df = gpd.read_file("regiao_metropolitana_bh-polygon/regiao_metropolitana_bh-polygon.shp")

# projetando e criando o campo 'escolhido'
map_df = map_df[["Name", 'geometry']].assign(escolhido= lambda x: True)

map_df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Pegando 3 amostras de regiões aleatórias

# %%
amostra = np.random.choice(range(map_df.shape[0]), replace=False, size=3)
map_df.loc[amostra, 'escolhido'] = False

# %%
amostra
# Out:
# array([27, 20, 12])

# %% [markdown]
# ## alternativamente, vamos usar uma amostra selecionada

# %%
amostra=[0,1,2,3]
map_df.loc[amostra, 'escolhido'] = False

# %% [markdown]
# ## Plotando eles

# %%
plt.axis('equal')
plt.suptitle("3 bairros aleatórios de BH")

nomes = map_df.loc[amostra]["Name"].values

fig, ((ax1, ax2),(ax3, ax4)) = plt.subplots(ncols=2, nrows=2, figsize=(10,10))


ax1.set_title("Localização")
map_df.plot(ax=ax1, column='escolhido', cmap='Set1')

ax2.set_title(nomes[0])
map_df.loc[[amostra[0]]].plot(ax=ax2)

ax3.set_title(nomes[1])
map_df.loc[[amostra[1]]].plot(ax=ax3)

ax4.set_title(nomes[2])
map_df.loc[[amostra[2]]].plot(ax=ax4)

fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-23bcf20a5fc0> in <module>
#       2 plt.suptitle("3 bairros aleatórios de BH")
#       3
# ----> 4 nomes = map_df.loc[amostra]["Name"].values
#       5
#       6 fig, ((ax1, ax2),(ax3, ax4)) = plt.subplots(ncols=2, nrows=2, figsize=(10,10))
#
# NameError: name 'amostra' is not defined

# %% [markdown]
# ## Plotando coordenadas especificas
# ### Pegando 3 pontos:

# %%
emge = [-19.9, -43.9]
inhotim = [-20.12, -44.2]
lagoaPampulha = [-19.85, -43.98]

coordenadas = np.stack([emge,inhotim, lagoaPampulha], axis=1)

# %% [markdown]
# ### plotando:

# %%
map_df.plot()

plt.plot(coordenadas[1], coordenadas[0], 'o', color='r')

# %%
map_df.plot(edgecolor=None)
# Out:
# <AxesSubplot:>
