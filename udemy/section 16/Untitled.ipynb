# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
base = pd.read_csv('iris.csv')
base
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
base.shape
# Out:
# (150, 5)

# %%
#Mudança da semente aleatória randômica para manter os resultados em várias execuções
np.random.seed(2345)

#150 amostras, de 0 a 1, com reposição, probabilidades equivalentes
amostra = np.random.choice(a = [False, True], size=150, replace=True, p=[0.7, 0.3])

print(len(amostra))
print(len(amostra[amostra == True]))
print(len(amostra[amostra == False]))
# Out:
# 150
# 49
# 101

# %%
base_final = base.loc[amostra == 0]
base_final.shape
# Out:
# (101, 5)

# %%
sns.pairplot(data=base, hue="class")
